# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.loadtxt("/1/popp.txt") #dtype={'names':('year', 'hare', 'lynx', 'carrot'), 'formats': (np.float,np.float,np.float,np.float)})

plt.xlabel('population')
plt.ylabel('years')
plt.plot (a[:,0], a[:,1])
plt.plot (a[:,0], a[:,2])
plt.plot (a[:,0], a[:,3])
plt.legend(("hares", "lynxes", "carrots"))
